# %%
import os
from dotenv import load_dotenv

load_dotenv()
print(os.getenv("MONGODB_URI"))
# Out:
# mongodb+srv://<db_username>:VlXHfDRb9zrtbg8N@cluster0.03malbp.mongodb.net/?appName=Cluster0

# %%
import pandas as pd
import pymongo

df = pd.read_csv("data/enron_spam_data.csv")
df.head()
# Out:
#    Message ID                       Subject  \
# 0           0  christmas tree farm pictures
# 1           1      vastar resources , inc .
# 2           2  calpine daily gas nomination
# 3           3                    re : issue
# 4           4     meter 7268 nov allocation
#
#                                              Message Spam/Ham        Date
# 0                                                NaN      ham  1999-12-10
# 1  gary , production from the high island larger ...      ham  1999-12-13
# 2             - calpine daily gas nomination 1 . doc      ham  1999-12-14
# 3  fyi - see note below - already done .\nstella\...      ham  1999-12-14
# 4  fyi .\n- - - - - - - - - - - - - - - - - - - -...      ham  1999-12-14

# %%
data = df.to_dict(orient="records")

# %%
import dotenv
import os
dotenv.load_dotenv()

client = pymongo.MongoClient(os.getenv("MONGODB_URL"))
data_base = client[os.getenv("DATA_BASE_NAME")]
collection = data_base[os.getenv("COLLECTION_NAME")]

# %%
# Uploading data to MongoDB
rec = collection.insert_many(data)

# %%
# Load back data from mongodb
df = pd.DataFrame(list(collection.find()))
df.head(2)
# Out:
#                         _id  Message ID                       Subject  \
# 0  6a65a1a47f267d63e5a6e7c1           0  christmas tree farm pictures
# 1  6a65a1a47f267d63e5a6e7c2           1      vastar resources , inc .
#
#                                              Message Spam/Ham        Date
# 0                                                NaN      ham  1999-12-10
# 1  gary , production from the high island larger ...      ham  1999-12-13
